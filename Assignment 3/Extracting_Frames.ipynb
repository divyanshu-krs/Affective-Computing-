# %%
# Ref - https://stackoverflow.com/questions/52534753/i-want-to-save-the-frames-of-video-at-certain-time-intervals-using-python-opencv 

import cv2
import os
import glob

sub_dirs = os.listdir('/content/drive/My Drive/Affective Computing/Assignment 3/Dataset/audio-video/')
sub_dirs.sort()
counter = 0
i = 0
for label, sub_dir in enumerate(sub_dirs):
  if(i<21):
    i+=1
    for file_name in glob.glob(os.path.join('/content/drive/My Drive/Affective Computing/Assignment 3/Dataset/audio-video/',sub_dir,"*.mp4")):

      #print(file_name)
      file = file_name.split('/')[-1]
      emotion_num = file.split('-')[2]
      print(emotion_num)
      cap = cv2.VideoCapture(file_name)

      time_skips = float(1000) #skip every 1 seconds
      count_1 = 0
      count_2 = 0
      count_3 = 0
      count_4 = 0
      count_5 = 0
      count_6 = 0
      count_7 = 0
      count_8 = 0

      success,image = cap.read()

      
      while success:
        counter+=1

        if (emotion_num == '01'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/neutral/'+file.split('.')[0]+"%d.jpg" % count_1, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_1*time_skips)) # move the time
          success,image = cap.read()
          count_1 += 1
          print('1')


        elif (emotion_num == '02'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/calm/'+file.split('.')[0]+"%d.jpg" % count_2, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_2*time_skips)) # move the time
          success,image = cap.read()
          count_2 += 1
          print('2')


        elif (emotion_num == '03'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/happy/'+file.split('.')[0]+"%d.jpg" % count_3, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_3*time_skips)) # move the time
          success,image = cap.read()
          count_3 += 1
          #print(done)
          print('3')


        elif (emotion_num == '04'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/sad/'+file.split('.')[0]+"%d.jpg" % count_4, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_4*time_skips)) # move the time
          success,image = cap.read()
          count_4 += 1
          print('4')


        elif (emotion_num == '05'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/angry/'+file.split('.')[0]+"%d.jpg" % count_5, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_5*time_skips)) # move the time
          success,image = cap.read()
          count_5 += 1 
          #print(done) 
          print('5') 


        elif (emotion_num == '06'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/fearful/'+file.split('.')[0]+"%d.jpg" % count_6, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_6*time_skips)) # move the time
          success,image = cap.read()
          count_6 += 1
          print('6')
          #print(done)


        elif (emotion_num == '07'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/disgust/'+file.split('.')[0]+"%d.jpg" % count_7, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_7*time_skips)) # move the time
          success,image = cap.read()
          count_7 += 1
          print('7')
          #print(done)


        elif (emotion_num == '08'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/my_data/surprised/'+file.split('.')[0]+"%d.jpg" % count_8, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_8*time_skips)) # move the time
          success,image = cap.read()
          count_8 += 1
          #print(count_8)
          print('8')      

# release after reading    
      cap.release()
      print(counter)
      
      
      
      
"""
(01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 =
disgust, 08 = surprised).
"""
# Out:
# Streaming output truncated to the last 5000 lines.
# 02
# 2
# 2
# 2
# 2
# 2
# 9347
# 02
# 2
# 2
# 2
# 2
# 2
# 9352
# 01
# 1
# 1
# 1
# 1
# 1
# 9357
# 03
# 3
# 3
# 3
# 3
# 3
# 9362
# 03
# 3
# 3
# 3
# 3
# 3
# 9367
# 02
# 2
# 2
# 2
# 2
# 2
# 9372
# 01
# 1
# 1
# 1
# 1
# 1
# 9377
# 02
# 2
# 2
# 2
# 2
# 2
# 9382
# 03
# 3
# 3
# 3
# 3
# 3
# 9387
# 03
# 3
# 3
# 3
# 3
# 3
# 9392
# 02
# 2
# 2
# 2
# 2
# 2
# 9397
# 01
# 1
# 1
# 1
# 1
# 1
# 9402
# 02
# 2
# 2
# 2
# 2
# 2
# 9407
# 08
# 8
# 8
# 8
# 8
# 8
# 9412
# 08
# 8
# 8
# 8
# 8
# 8
# 9417
# 05
# 5
# 5
# 5
# 5
# 5
# 9422
# 06
# 6
# 6
# 6
# 6
# 6
# 9427
# 06
# 6
# 6
# 6
# 6
# 6
# 9432
# 05
# 5
# 5
# 5
# 5
# 5
# 9437
# 07
# 7
# 7
# 7
# 7
# 7
# 9442
# 04
# 4
# 4
# 4
# 4
# 4
# 9447
# 04
# 4
# 4
# 4
# 4
# 4
# 9452
# 07
# 7
# 7
# 7
# 7
# 7
# 7
# 9458
# 08
# 8
# 8
# 8
# 8
# 8
# 9463
# 08
# 8
# 8
# 8
# 8
# 8
# 9468
# 05
# 5
# 5
# 5
# 5
# 5
# 9473
# 06
# 6
# 6
# 6
# 6
# 6
# 9478
# 06
# 6
# 6
# 6
# 6
# 6
# 9483
# 05
# 5
# 5
# 5
# 5
# 5
# 5
# 9489
# 07
# 7
# ...

# %%
# Ref - https://stackoverflow.com/questions/52534753/i-want-to-save-the-frames-of-video-at-certain-time-intervals-using-python-opencv 



sub_dirs = os.listdir('/content/drive/My Drive/Affective Computing/Assignment 3/Dataset/audio-video/')
sub_dirs.sort()
counter = 0
i = 0
for label, sub_dir in enumerate(sub_dirs):

  if (int(sub_dir.split('_')[-1]) >= 21):
        
    for file_name in glob.glob(os.path.join('/content/drive/My Drive/Affective Computing/Assignment 3/Dataset/audio-video/',sub_dir,"*.mp4")):

      #print(file_name)
      file = file_name.split('/')[-1]
      emotion_num = file.split('-')[2]
      print(emotion_num)
      cap = cv2.VideoCapture(file_name)

      time_skips = float(1000) #skip every 1 seconds
      count_1 = 0
      count_2 = 0
      count_3 = 0
      count_4 = 0
      count_5 = 0
      count_6 = 0
      count_7 = 0
      count_8 = 0

      success,image = cap.read()

      
      while success:
        counter+=1

        if (emotion_num == '01'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/neutral/'+file.split('.')[0]+"%d.jpg" % count_1, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_1*time_skips)) # move the time
          success,image = cap.read()
          count_1 += 1
          print('1')


        elif (emotion_num == '02'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/calm/'+file.split('.')[0]+"%d.jpg" % count_2, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_2*time_skips)) # move the time
          success,image = cap.read()
          count_2 += 1
          print('2')


        elif (emotion_num == '03'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/happy/'+file.split('.')[0]+"%d.jpg" % count_3, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_3*time_skips)) # move the time
          success,image = cap.read()
          count_3 += 1
          #print(done)
          print('3')


        elif (emotion_num == '04'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/sad/'+file.split('.')[0]+"%d.jpg" % count_4, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_4*time_skips)) # move the time
          success,image = cap.read()
          count_4 += 1
          print('4')


        elif (emotion_num == '05'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/angry/'+file.split('.')[0]+"%d.jpg" % count_5, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_5*time_skips)) # move the time
          success,image = cap.read()
          count_5 += 1 
          #print(done) 
          print('5') 


        elif (emotion_num == '06'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/fearful/'+file.split('.')[0]+"%d.jpg" % count_6, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_6*time_skips)) # move the time
          success,image = cap.read()
          count_6 += 1
          print('6')
          #print(done)


        elif (emotion_num == '07'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/disgust/'+file.split('.')[0]+"%d.jpg" % count_7, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_7*time_skips)) # move the time
          success,image = cap.read()
          count_7 += 1
          print('7')
          #print(done)


        elif (emotion_num == '08'):
          cv2.imwrite('/content/drive/My Drive/Affective Computing/Assignment 3/test_data/surprised/'+file.split('.')[0]+"%d.jpg" % count_8, image)     
          cap.set(cv2.CAP_PROP_POS_MSEC,(count_8*time_skips)) # move the time
          success,image = cap.read()
          count_8 += 1
          #print(count_8)
          print('8')      

# release after reading    
      cap.release()
    print(counter)
      
      
      
      
"""
(01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 =
disgust, 08 = surprised).
"""
